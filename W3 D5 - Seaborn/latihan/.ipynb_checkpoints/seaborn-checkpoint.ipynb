# %% [markdown]
# Lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# # Relation chart

# %% [markdown]
# Line plot

# %%
#matplotlib plt.plot()

plt.figure(figsize=(12,8))
sns.lineplot(x='year', y='passengers', data=df) #df['year]
plt.show()

# %%
#matplotlib argumen color/c
plt.figure(figsize=(12,8))
sns.lineplot( x='year', y='passengers',marker='o', data=df, hue='month') #mengubah color saja gunakan palette, hue = color datapoint based on data
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
#matplotlib plt.scatter()

plt.figure(figsize=(12,8))
# palette = "ch:r=-.2,d=.3_r"

sns.scatterplot(x='year', y='passengers', data=df, hue='month', size='month', linewidth =0, palette=palette) #size >> mengubaha data menjadi ukuran visual, sizes=memperbesar ukuran datapoint (10,20), linewidth=0
plt.show()

# %% [markdown]
# ### Distributional plot

# %%
sns.set(rc={'figure.figsize':(14,10)})
sns.kdeplot(df['passengers']);

# %%
sns.distplot(df['passengers']);

# %%
sns.kdeplot(df['year'], df['passengers'], cmap='Greens');

# %% [markdown]
# ### CAtegorical data

# %%
sns.catplot?

# %%
#sns.set(rc={'figure.figsize':(16,12)})
#barplot
sns.catplot(x='year', y='passengers', data=df, kind='bar', height=8);

# %%
#boxplot
sns.catplot(x='year', y='passengers', data=df, kind='box', height=8); #tidak menampilkan outlier showfliers=False

# %%
sns.boxplot(df['passengers'])

# %%
pass_month = df[df['month']=='Jun']
pass_month
# Out:
#      year month  passengers
# 5    1949   Jun         135
# 17   1950   Jun         149
# 29   1951   Jun         178
# 41   1952   Jun         218
# 53   1953   Jun         243
# 65   1954   Jun         264
# 77   1955   Jun         315
# 89   1956   Jun         374
# 101  1957   Jun         422
# 113  1958   Jun         435
# 125  1959   Jun         472
# 137  1960   Jun         535

# %%
pass_month1 = df[df['month']=='Dec']
pass_month1
# Out:
#      year month  passengers
# 11   1949   Dec         118
# 23   1950   Dec         140
# 35   1951   Dec         166
# 47   1952   Dec         194
# 59   1953   Dec         201
# 71   1954   Dec         229
# 83   1955   Dec         278
# 95   1956   Dec         306
# 107  1957   Dec         336
# 119  1958   Dec         337
# 131  1959   Dec         405
# 143  1960   Dec         432

# %%
data = pass_month.sort_values('passengers', ascending=False).head(5)

chart = sns.barplot(x = 'year', y='passengers',data=data)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
for p in chart.patches:
    chart.annotate("{:,.2f}".format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
#menampilkan beberapa kolom, bisa tambahkan argumen col=' '
sns.catplot(x='year', y='passengers', data=df, col = 'month', kind='bar', height=8);

# %% [markdown]
# ### Regression plot

# %%
plt.figure(figsize=(12,8))
sns.regplot(x='year', y='passengers', data=df);

# %% [markdown]
# ### Pairplot

# %%
pallete = 
sns.pairplot(df, hue='month'); #vars=[] #corner=True

# %%
sns.pairplot?

# %% [markdown]
# ### Jointplot

# %%
with sns.axes_style('dark'): #darkgrid
  sns.jointplot('year', 'passengers', kind='kde', data=df);

# %%
with sns.axes_style('white'):
  sns.jointplot(x='year', y='passengers', data=df, kind='scatter');

# %%
import numpy as np
import pandas as pd

data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    print (col)
    plt.hist(data[col], bins=10, density=True, alpha=0.5)
# Out:
# x
# y

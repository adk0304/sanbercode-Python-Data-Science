# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:

# %% [markdown]
# Univariate adalah teknik untuk memahami, mengeksplorasi, dan menganalisis 1 data tunggal / 1 variabel
#
# ---
# Bivariate adalah teknik untuk menganalisis 2 data untuk menemukan hubungan antar 2 data tersebut
#
# ---
# Multivariate adalah teknik untuk menganalisis banyak data / lebih dari 2 variabel dalam waktu yang sama
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#code here
df.dropna()
df2 = df.groupby('species').mean()
df2
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.791391      18.346358         189.953642  3700.662252
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.504878      14.982114         217.186992  5076.016260

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#code here
plt.figure(figsize=(15,8))
data = df2['flipper_length_mm']
label = data.index
warna = sns.color_palette('tab10')
print('Pie Chart')
plt.pie(data, labels = label, colors=warna, autopct='%1.2f%%')
plt.show()

plt.figure(figsize=(10,6))
print('Bar Chart')
plt.hist(x=df['body_mass_g'], bins=10)
plt.xlabel('Body_mass_g')
plt.ylabel('Count')
plt.show()
# Out:
# Pie Chart
# Bar Chart

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa:

# %% [markdown]
# Berdasarkan Grafik pertama dapat diambil insight bahwa panjang sirip pinguin dari 3 spesies yang terpanjang sampai terpendek yakni spesies gentoo, spesies chinstrap, dan spesies Adeile.
#
# Selisih panjang sirip dari spesies sirip terpanjang gentoo dan chinstrap sebesar 3.54%
# jika dibanding dengan spesies Adile sebesar 4.52%
#
# jika spesies Chinstrap dengan adlie memiliki perbedaan sebesar 0.98% panjangnya
#
# -----
#
# Berdasarkan Grafik kedua dapat diambil insight bahwa berat badan pingunin sangat beragam.
# pinguin teringan dengan berat 3000g sebanyak 15 ekor
# pinguin terberat dengan berat sikitar 6000g sebanyak kurang dari 10
# Berat terbanyak yakni 3500g dengan jumlah 70 ekor pinguin

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
#code here

plt.figure(figsize=(10,6))
print('Catplot')
sns.catplot(x="sex", y="bill_length_mm", kind="bar", data=df)
plt.show()

print('Scatter Plot')

plt.figure(figsize=(12,8))
sns.relplot(x="body_mass_g", y="flipper_length_mm", hue="bill_length_mm", data=df);
plt.show()
# Out:
# Catplot
# Scatter Plot

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa:

# %% [markdown]
# Berdasarkan grafik pertama
# panjang paruh untuk pinguin jantan lebih panjang dari pada panjang paruh pinguin betina
#
# berdasarkan grafik kedua
# berat badan dari pinguin berpengaruh positif terhadap panjang siripnya
# jika melihat dari perbedaan warna pada point grafik, itu menandakan perbedaan panjang paruh yang dapat ditarik kesimpulan juga bahwa panjang paruh tidak hanya dipengaruhi oleh berat badan dan panjang sirip saja, tapi bisa dipengaruhi oleh faktor lain karena tidak semua pinguin yang memiliki berat badan kecil dan panjang sirip kecil memiliki panjang paruh yang kecil juga
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
#code here
sns.pairplot(df, height=2.5)

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# Jika dilihat dari grafik panjang paruh dengan tinggi paruh maka dapat dilihat jika semakin panjang paruh pinguin belum tentu pinguin tersebut memilki paruh yang tinggi, bahkan banyak pinguin yang memiliki paruh yang pendek namun paruh tersebut tidak tinggi.
#
# jika dilihat dari panjang paruh dengan panjang sirip maka dapat disimpulkan bahwa panjang paruh berpengaruh positif terhadap panjang sirip walaupun ada beberapa pinguin yang memilki paruh yang panjang tapi siripnya pendek
#
# Jika dilihat dari panjang paruh dengan berat badan pingun maka dapat disimpulkan memilki pengaruh positif,
# rata-rata semakin panjang paruh maka semakin berat pinguin tersebut
#
# jika dilihat berdasarkan tinggi paruh dengan panjang sirip maka dapat dilihat jika paruh tinggi , sirip semakin pendek
# jika paruh pendek, sirip panjang
#
# jika dilihat berdasarkan tinggi paruh dengan berat badan maka semakin pendek paruh maka semakin berat pinguin tersebut
#
# jika berdasarkan panjang sirip dengan berat badan dapat diambil kesimpulkan semakin panjang sirip nya maka semakin berat massa tubuh pinguin tersebut
